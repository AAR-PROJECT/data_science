# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("StudentsPerformance.csv")

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
sns.countplot(data=df,x="math score",hue="race/ethnicity")

# %%
sns.boxplot(data=df,palette="coolwarm",x="race/ethnicity",y="math score")

# %%
sns.boxplot(data=df,palette="coolwarm",x="race/ethnicity",y="reading score")

# %%
sns.boxplot(data=df,palette="coolwarm",x="race/ethnicity",y="writing score")

# %%
sns.violinplot(data=df,palette="coolwarm",x="race/ethnicity",y="math score",hue="gender")

# %%
sns.violinplot(data=df,palette="coolwarm",x="race/ethnicity",y="writing score",hue="gender")

# %%
sns.violinplot(data=df,palette="coolwarm",x="race/ethnicity",y="writing score",hue="gender")
sns.swarmplot(data=df,x="race/ethnicity",y="writing score",size=4,hue="gender")

# %%
sns.violinplot(data=df,x="race/ethnicity",y="writing score",palette="Set1",hue="gender",split=True)

# %%
sns.violinplot(data=df,x="race/ethnicity",y="math score",palette="Set1",hue="gender",split=True)

# %%
sns.violinplot(data=df,x="parental level of education",y="math score",palette="Set1")

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
g = sns.FacetGrid(data=df,col="parental level of education")

# %%
g = sns.FacetGrid(data=df,row="parental level of education",col="gender")
g.map(plt.scatter,"writing score","math score")

# %%
x= df.loc[:,["reading score"]].values
y = df.loc[:,["writing score"]].values

# %%
x
# Out:
# array([[ 72],
#        [ 90],
#        [ 95],
#        [ 57],
#        [ 78],
#        [ 83],
#        [ 95],
#        [ 43],
#        [ 64],
#        [ 60],
#        [ 54],
#        [ 52],
#        [ 81],
#        [ 72],
#        [ 53],
#        [ 75],
#        [ 89],
#        [ 32],
#        [ 42],
#        [ 58],
#        [ 69],
#        [ 75],
#        [ 54],
#        [ 73],
#        [ 71],
#        [ 74],
#        [ 54],
#        [ 69],
#        [ 70],
#        [ 70],
#        [ 74],
#        [ 65],
#        [ 72],
#        [ 42],
#        [ 87],
#        [ 81],
#        [ 81],
#        [ 64],
#        [ 90],
#        [ 56],
#        [ 61],
#        [ 73],
#        [ 58],
#        [ 65],
#        [ 56],
#        [ 54],
#        [ 65],
#        [ 71],
#        [ 74],
#        [ 84],
#        [ 55],
#        [ 69],
#        [ 44],
#        [ 78],
#        [ 84],
#        [ 41],
#        [ 85],
#        [ 55],
#        [ 59],
#        [ 17],
#        [ 74],
#        [ 39],
# ...

# %%
y
# Out:
# array([[ 74],
#        [ 88],
#        [ 93],
#        [ 44],
#        [ 75],
#        [ 78],
#        [ 92],
#        [ 39],
#        [ 67],
#        [ 50],
#        [ 52],
#        [ 43],
#        [ 73],
#        [ 70],
#        [ 58],
#        [ 78],
#        [ 86],
#        [ 28],
#        [ 46],
#        [ 61],
#        [ 63],
#        [ 70],
#        [ 53],
#        [ 73],
#        [ 80],
#        [ 72],
#        [ 55],
#        [ 75],
#        [ 65],
#        [ 75],
#        [ 74],
#        [ 61],
#        [ 65],
#        [ 38],
#        [ 82],
#        [ 79],
#        [ 83],
#        [ 59],
#        [ 88],
#        [ 57],
#        [ 54],
#        [ 68],
#        [ 65],
#        [ 66],
#        [ 54],
#        [ 57],
#        [ 62],
#        [ 76],
#        [ 76],
#        [ 82],
#        [ 48],
#        [ 68],
#        [ 42],
#        [ 75],
#        [ 87],
#        [ 43],
#        [ 86],
#        [ 49],
#        [ 58],
#        [ 10],
#        [ 72],
#        [ 34],
# ...

# %%
plt.scatter(x,y,color="blue")

# %%
plt.scatter(x,y,color="red")
plt.title("Score Membaca vs Score Menulis")
plt.xlabel("Score Membaca")
plt.ylabel("Score Menulis")
# Out:
# Text(0, 0.5, 'Score Menulis')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.05,random_state=8)

# %%
x_train
# Out:
# array([[ 75],
#        [ 76],
#        [ 77],
#        [ 34],
#        [ 54],
#        [ 70],
#        [ 84],
#        [ 62],
#        [ 71],
#        [ 77],
#        [ 81],
#        [ 67],
#        [ 75],
#        [ 70],
#        [ 60],
#        [ 59],
#        [ 62],
#        [ 59],
#        [ 72],
#        [ 79],
#        [ 82],
#        [ 67],
#        [ 60],
#        [ 64],
#        [ 62],
#        [ 45],
#        [ 61],
#        [ 51],
#        [ 67],
#        [ 67],
#        [ 78],
#        [ 74],
#        [ 74],
#        [ 67],
#        [ 79],
#        [ 42],
#        [ 74],
#        [ 77],
#        [ 87],
#        [ 58],
#        [ 53],
#        [100],
#        [ 78],
#        [ 49],
#        [ 72],
#        [ 85],
#        [ 89],
#        [ 76],
#        [ 73],
#        [ 72],
#        [ 64],
#        [ 49],
#        [ 64],
#        [ 95],
#        [ 46],
#        [ 76],
#        [ 37],
#        [ 85],
#        [ 87],
#        [ 39],
#        [ 76],
#        [ 81],
# ...

# %%
x_test
# Out:
# array([[75],
#        [42],
#        [48],
#        [23],
#        [74],
#        [68],
#        [97],
#        [77],
#        [64],
#        [43],
#        [67],
#        [64],
#        [60],
#        [73],
#        [80],
#        [58],
#        [44],
#        [61],
#        [72],
#        [74],
#        [62],
#        [72],
#        [70],
#        [92],
#        [63],
#        [89],
#        [65],
#        [69],
#        [72],
#        [81],
#        [52],
#        [68],
#        [49],
#        [59],
#        [79],
#        [64],
#        [69],
#        [67],
#        [67],
#        [61],
#        [79],
#        [50],
#        [59],
#        [81],
#        [72],
#        [51],
#        [70],
#        [69],
#        [61],
#        [88]], dtype=int64)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(x_train,y_train,color="red")
plt.plot(x_train,regressor.predict(x_train),color="blue")
plt.title("Score Membaca vs Score Menulis")
plt.xlabel("Score Membaca")
plt.ylabel("Score Menulis")
# Out:
# Text(0, 0.5, 'Score Menulis')

# %%
plt.scatter(x_test,y_test,color="red")
plt.plot(x_test,regressor.predict(x_test),color="blue")

plt.title("Score Membaca vs Score Menulis")
plt.xlabel("Score Membaca")
plt.ylabel("Score Menulis")
# Out:
# Text(0, 0.5, 'Score Menulis')
